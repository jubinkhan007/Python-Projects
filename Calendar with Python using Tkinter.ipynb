# %%
# !pip install tk
# Out:
# Collecting tk
#   Downloading tk-0.1.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: tk
# Successfully installed tk-0.1.0

# %%
#import calendar module
import calendar
#import tkinter module
from tkinter import *

# %%
#This function displays calendar for a given year
def showCalender():
    gui = Tk()
    gui.config(background='grey')
    gui.title("Calender for the year")
    gui.geometry("550x600")
    year = int(year_field.get())
    gui_content= calendar.calendar(year)
    calYear = Label(gui, text= gui_content, font= "Consolas 10 bold")
    calYear.grid(row=5, column=1,padx=20)
    gui.mainloop()

# %%
#Driver code
if __name__=='__main__':
    new = Tk()
    new.config(background='grey')
    new.title("Calender")
    new.geometry("250x140")
    cal = Label(new, text="Calender",bg='grey',font=("times", 28, "bold"))
    #Label for enter year
    year = Label(new, text="Enter year", bg='dark grey')
    #text box for year input
    year_field=Entry(new)
    button = Button(new, text='Show Calender',fg='Black',bg='Blue',command=showCalender)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-4-883f77003351> in <module>()
#       1 #Driver code
#       2 if __name__=='__main__':
# ----> 3     new = Tk()
#       4     new.config(background='grey')
#       5     new.title("Calender")
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
#adjusting widgets in position
cal.grid(row=1, column=1)
year.grid(row=2, column=1)
year_field.grid(row=3, column=1)
button.grid(row=4, column=1)
Exit.grid(row=6, column=1)
new.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d69e94c393b2> in <module>()
#       1 #adjusting widgets in position
# ----> 2 cal.grid(row=1, column=1)
#       3 year.grid(row=2, column=1)
#       4 year_field.grid(row=3, column=1)
#       5 button.grid(row=4, column=1)
#
# NameError: name 'cal' is not defined
